# %%
import numpy as np
import pandas as pd
import pprint
pd.options.display.max_columns = None
train_genba = pd.read_csv('dataset/train_genba.tsv', delimiter='\t')
print(train_genba.describe(include='all'))
# Out:
#               pj_no      jukyo  chiseki_js_hb  chiseki_kb_hb        yoto1  \
# count   2781.000000       2781    2781.000000    2780.000000         2781
# unique          NaN       1234            NaN            NaN           12
# top             NaN  埼玉県入間市東藤沢            NaN            NaN  第一種低層住居専用地域
# freq            NaN         17            NaN            NaN          935
# mean    1390.000000        NaN     342.503412     363.245191          NaN
# std      802.949874        NaN     405.645892     456.271346          NaN
# min        0.000000        NaN      39.160000      39.160000          NaN
# 25%      695.000000        NaN     125.600000     125.475000          NaN
# 50%     1390.000000        NaN     202.970000     206.575000          NaN
# 75%     2085.000000        NaN     395.510000     407.965000          NaN
# max     2780.000000        NaN    5343.730000    5343.710000          NaN
#
#           yoto2      kempei1      kempei2      yoseki1      yoseki2 josui  \
# count       151  2781.000000  2539.000000  2781.000000  2539.000000  2781
# unique        9          NaN          NaN          NaN          NaN     2
# top     第一種住居地域          NaN          NaN          NaN          NaN    公営
# freq         48          NaN          NaN          NaN          NaN  2748
# mean        NaN    57.856886     3.489563   165.490831    10.283576   NaN
# std         NaN     4.902908    13.929951    52.596793    42.423601   NaN
# min         NaN    40.000000     0.000000    60.000000     0.000000   NaN
# 25%         NaN    60.000000     0.000000   100.000000     0.000000   NaN
# 50%         NaN    60.000000     0.000000   200.000000     0.000000   NaN
# 75%         NaN    60.000000     0.000000   200.000000     0.000000   NaN
# max         NaN    80.000000    80.000000   400.000000   200.000000   NaN
#
#        gesui   gas  usui   tateuri_su  tochiuri_su     joken_su  hy1f_date_su  \
# count   2781  2781  2781  2780.000000  2687.000000  2687.000000        2684.0
# unique     2     3     3          NaN          NaN          NaN           NaN
# top     公共下水  都市ガス  宅内処理          NaN          NaN          NaN           NaN
# freq    2480  1867  2614          NaN          NaN          NaN           NaN
# mean     NaN   NaN   NaN     2.228058     0.090063     0.008932           0.0
# std      NaN   NaN   NaN     2.272812     0.669572     0.184856           0.0
# min      NaN   NaN   NaN     0.000000     0.000000     0.000000           0.0
# 25%      NaN   NaN   NaN     1.000000     0.000000     0.000000           0.0
# 50%      NaN   NaN   NaN     1.000000     0.000000     0.000000           0.0
# 75%      NaN   NaN   NaN     3.000000     0.000000     0.000000           0.0
# max      NaN   NaN   NaN    31.000000    18.000000     6.000000           0.0
#
#         hy2f_date_su  hy3f_date_su road1_hk road1_sb     road1_fi  \
# count    2778.000000   2713.000000     2781     2781  2781.000000
# unique           NaN           NaN        9        3          NaN
# top              NaN           NaN        南       公道          NaN
# freq             NaN           NaN      545     2437          NaN
# mean        2.147588      0.094729      NaN      NaN     5.443024
# std         2.341827      0.425347      NaN      NaN     2.692177
# min         0.000000      0.000000      NaN      NaN     0.900000
# 25%         1.000000      0.000000      NaN      NaN     4.000000
# 50%         1.000000      0.000000      NaN      NaN     4.600000
# 75%         2.000000      0.000000      NaN      NaN     6.000000
# max        31.000000      7.000000      NaN      NaN    57.000000
#
#            road1_mg road2_hk road2_sb     road2_fi     road2_mg road3_hk  \
# count   2781.000000     1025     1025  2646.000000  2646.000000      156
# unique          NaN        8        3          NaN          NaN        8
# top             NaN        西       公道          NaN          NaN        北
# freq            NaN      210      852          NaN          NaN       38
# mean      14.556310      NaN      NaN     2.058050     6.821833      NaN
# std        9.644642      NaN      NaN     3.495823    11.654770      NaN
# min        0.000000      NaN      NaN     0.000000     0.000000      NaN
# 25%        9.000000      NaN      NaN     0.000000     0.000000      NaN
# 50%       12.000000      NaN      NaN     0.000000     0.000000      NaN
# 75%       17.500000      NaN      NaN     4.000000    11.200000      NaN
# max      148.000000      NaN      NaN    71.000000   110.500000      NaN
#
#        road3_sb     road3_fi     road3_mg road4_hk road4_sb     road4_fi  \
# count       156  2564.000000  2564.000000       15       15  2555.000000
# unique        3          NaN          NaN        7        2          NaN
# top          公道          NaN          NaN        東       公道          NaN
# freq        126          NaN          NaN        5       12          NaN
# mean        NaN     0.307414     1.475676      NaN      NaN     0.030215
# std         NaN     1.413153     7.845518      NaN      NaN     0.422909
# min         NaN     0.000000     0.000000      NaN      NaN     0.000000
# 25%         NaN     0.000000     0.000000      NaN      NaN     0.000000
# 50%         NaN     0.000000     0.000000      NaN      NaN     0.000000
# 75%         NaN     0.000000     0.000000      NaN      NaN     0.000000
# max         NaN    26.000000   157.400000      NaN      NaN    12.000000
#
#            road4_mg kaoku_um     kaoku_hb  yheki_kotei yheki_umu yheki_yohi  \
# count   2555.000000     2781  2717.000000  2781.000000      2781       2781
# unique          NaN        2          NaN          NaN         2          2
# top             NaN      （無）          NaN          NaN       （無）       （不要）
# freq            NaN     2030          NaN          NaN      2664       2638
# mean       0.249237      NaN    34.910121     0.349180       NaN        NaN
# std        3.806706      NaN    96.187931     0.428229       NaN        NaN
# min        0.000000      NaN     0.000000     0.000000       NaN        NaN
# 25%        0.000000      NaN     0.000000     0.100000       NaN        NaN
# 50%        0.000000      NaN     0.000000     0.300000       NaN        NaN
# 75%        0.000000      NaN    55.480000     0.500000       NaN        NaN
# max       86.000000      NaN  1846.770000     6.000000       NaN        NaN
#
#         gk_sho_kyori  gk_chu_kyori kborjs hw_status toshikuiki1 toshikuiki2  \
# count    2781.000000   2781.000000   2781      2781        2781          25
# unique           NaN           NaN      3         7           4           3
# top              NaN           NaN     公簿        更地       市街化区域       市街化区域
# freq             NaN           NaN   1461      1538        2544          22
# mean      806.088098   1198.573535    NaN       NaN         NaN         NaN
# std       472.965370    649.397399    NaN       NaN         NaN         NaN
# min         6.000000     10.000000    NaN       NaN         NaN         NaN
# 25%       480.000000    720.000000    NaN       NaN         NaN         NaN
# 50%       720.000000   1100.000000    NaN       NaN         NaN         NaN
# 75%      1090.000000   1600.000000    NaN       NaN         NaN         NaN
# max      8800.000000   4800.000000    NaN       NaN         NaN         NaN
#
#        kodochiku chikukeikaku keikakuroad kaihatsukyoka t53kyoka hokakyoka  \
# count       2781         2781        2781          2781     2781      2781
# unique         6            2           2             2        2         2
# top          指定無          （無）         （無）          （不要）     （不要）      （不要）
# freq        2549         2476        2708          2453     2721      2329
# mean         NaN          NaN         NaN           NaN      NaN       NaN
# std          NaN          NaN         NaN           NaN      NaN       NaN
# min          NaN          NaN         NaN           NaN      NaN       NaN
# 25%          NaN          NaN         NaN           NaN      NaN       NaN
# 50%          NaN          NaN         NaN           NaN      NaN       NaN
# 75%          NaN          NaN         NaN           NaN      NaN       NaN
# max          NaN          NaN         NaN           NaN      NaN       NaN
#
#        bokachiiki   minmenseki hokakisei1 hokakisei2 hokakisei3 hokakisei4  \
# count        2781  1405.000000        734        260         73         19
# unique          6          NaN         20         19          7          3
# top         防火指定無          NaN        景観法        農地法      埋蔵文化財        公拡法
# freq         1572          NaN        508        164         36         16
# mean          NaN    62.815658        NaN        NaN        NaN        NaN
# std           NaN    73.641608        NaN        NaN        NaN        NaN
# min           NaN     0.000000        NaN        NaN        NaN        NaN
# 25%           NaN     0.000000        NaN        NaN        NaN        NaN
# 50%           NaN     0.000000        NaN        NaN        NaN        NaN
# 75%           NaN   110.000000        NaN        NaN        NaN        NaN
# max           NaN   300.000000        NaN        NaN        NaN        NaN
#
#        kinshijiko     rosenka_hb        koji_hb      kijun_hb  mseki_yt_hb  \
# count        2781    2781.000000    2781.000000  2.781000e+03  2781.000000
# unique          2            NaN            NaN           NaN          NaN
# top           （無）            NaN            NaN           NaN          NaN
# freq         2749            NaN            NaN           NaN          NaN
# mean          NaN   80798.907587  118735.922330  1.180793e+05   333.810086
# std           NaN   44506.309507   50147.981595  6.062975e+04   385.683845
# min           NaN       0.000000   12000.000000  0.000000e+00    39.160000
# 25%           NaN   60000.000000   87000.000000  8.530000e+04   123.430000
# 50%           NaN   83000.000000  113000.000000  1.130000e+05   201.980000
# 75%           NaN  105000.000000  143000.000000  1.470000e+05   389.680000
# max           NaN  320000.000000  486000.000000  1.050000e+06  5026.380000
#
#         mseki_rd_hb  mseki_dp_hb  tc_mseki_min_hb  tc_mseki_max_hb  \
# count   2763.000000  2762.000000      2781.000000      2781.000000
# unique          NaN          NaN              NaN              NaN
# top             NaN          NaN              NaN              NaN
# freq            NaN          NaN              NaN              NaN
# mean      14.505197     0.871314       136.062704       218.492384
# std       62.463943    14.702664        50.724854      3966.829682
# min        0.000000     0.000000         0.000000         0.000000
# 25%        0.000000     0.000000       104.000000       109.180000
# 50%        0.000000     0.000000       124.490000       132.910000
# 75%        0.000000     0.000000       153.800000       163.850000
# max      835.260000   604.470000       643.990000    209315.000000
#
#         tt_mseki_min_hb  tt_mseki_max_hb  tc_mseki_avg_hb  tt_mseki_avg_hb  \
# count       2781.000000      2781.000000      2781.000000      2780.000000
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean          98.446278       100.516728       142.626314        99.732180
# std           16.699816        15.133068        67.285832        16.367244
# min            0.000000         0.000000        39.160000         0.000000
# 25%           95.870000        96.880000       107.020000        96.000000
# 50%          101.430000       103.680000       130.600000       102.500000
# 75%          105.990000       105.990000       160.910000       105.990000
# max          126.690000       180.890000      1945.500000       320.450000
#
#        fi4m_yohi fi3m_yohi   fi4m_kyori   fi3m_kyori bus_yohi      bus_hon  \
# count       2781      2781  2635.000000  2628.000000     2781  1179.000000
# unique         2         3          NaN          NaN        2          NaN
# top         （不要）      （不要）          NaN          NaN     （不要）          NaN
# freq        2719      2766          NaN          NaN     2138          NaN
# mean         NaN       NaN     0.907670     0.170696      NaN    26.761662
# std          NaN       NaN    10.023664     3.816134      NaN    39.676836
# min          NaN       NaN     0.000000     0.000000      NaN     0.000000
# 25%          NaN       NaN     0.000000     0.000000      NaN     0.000000
# 50%          NaN       NaN     0.000000     0.000000      NaN    10.000000
# 75%          NaN       NaN     0.000000     0.000000      NaN    48.000000
# max          NaN       NaN   290.000000   150.000000      NaN   665.000000
#
#        sho_conv sho_super sho_shoten sho_market shu_jutaku shu_park shu_shop  \
# count      1215       729         89         83       2510       72       19
# unique        1         1          1          1          1        1        1
# top           ○         ○          ○          ○          ○        ○        ○
# freq       1215       729         89         83       2510       72       19
# mean        NaN       NaN        NaN        NaN        NaN      NaN      NaN
# std         NaN       NaN        NaN        NaN        NaN      NaN      NaN
# min         NaN       NaN        NaN        NaN        NaN      NaN      NaN
# 25%         NaN       NaN        NaN        NaN        NaN      NaN      NaN
# 50%         NaN       NaN        NaN        NaN        NaN      NaN      NaN
# 75%         NaN       NaN        NaN        NaN        NaN      NaN      NaN
# max         NaN       NaN        NaN        NaN        NaN      NaN      NaN
#
#        shu_factory shu_hvline shu_tower shu_bochi shu_sogi shu_zoki shu_kokyo  \
# count           42         10         7        12        1       28        14
# unique           1          1         1         1        1        1         1
# top              ○          ○         ○         ○        ○        ○         ○
# freq            42         10         7        12        1       28        14
# mean           NaN        NaN       NaN       NaN      NaN      NaN       NaN
# std            NaN        NaN       NaN       NaN      NaN      NaN       NaN
# min            NaN        NaN       NaN       NaN      NaN      NaN       NaN
# 25%            NaN        NaN       NaN       NaN      NaN      NaN       NaN
# 50%            NaN        NaN       NaN       NaN      NaN      NaN       NaN
# 75%            NaN        NaN       NaN       NaN      NaN      NaN       NaN
# max            NaN        NaN       NaN       NaN      NaN      NaN       NaN
#
#        shu_highway shu_kaido shu_line_ari shu_line_nashi shu_soon  \
# count           10        50           36             31       13
# unique           1         1            1              1        1
# top              ○         ○            ○              ○        ○
# freq            10        50           36             31       13
# mean           NaN       NaN          NaN            NaN      NaN
# std            NaN       NaN          NaN            NaN      NaN
# min            NaN       NaN          NaN            NaN      NaN
# 25%            NaN       NaN          NaN            NaN      NaN
# 50%            NaN       NaN          NaN            NaN      NaN
# 75%            NaN       NaN          NaN            NaN      NaN
# max            NaN       NaN          NaN            NaN      NaN
#
#           gk_yoc_tm    gk_sho_tm    gk_chu_tm rs_e_kdate2 rs_e_kdate3  \
# count   2781.000000  2781.000000  2781.000000        1747          52
# unique          NaN          NaN          NaN           1           1
# top             NaN          NaN          NaN           ○           ○
# freq            NaN          NaN          NaN        1747          52
# mean      11.432938    10.392665    15.265013         NaN         NaN
# std        7.498795     5.903152     8.116501         NaN         NaN
# min        0.000000     1.000000     1.000000         NaN         NaN
# 25%        6.000000     6.000000     9.000000         NaN         NaN
# 50%       10.000000     9.000000    14.000000         NaN         NaN
# 75%       15.000000    14.000000    20.000000         NaN         NaN
# max       91.000000   110.000000    60.000000         NaN         NaN
#
#        rs_e_parking rs_e_zoki rs_e_m_ari rs_e_m_nashi rs_e_tahata rs_w_kdate2  \
# count           123        20         19           47         107        1737
# unique            1         1          1            1           1           1
# top               ○         ○          ○            ○           ○           ○
# freq            123        20         19           47         107        1737
# mean            NaN       NaN        NaN          NaN         NaN         NaN
# std             NaN       NaN        NaN          NaN         NaN         NaN
# min             NaN       NaN        NaN          NaN         NaN         NaN
# 25%             NaN       NaN        NaN          NaN         NaN         NaN
# 50%             NaN       NaN        NaN          NaN         NaN         NaN
# 75%             NaN       NaN        NaN          NaN         NaN         NaN
# max             NaN       NaN        NaN          NaN         NaN         NaN
#
#        rs_w_kdate3 rs_w_parking rs_w_zoki rs_w_m_ari rs_w_m_nashi rs_w_tahata  \
# count           36          107        20         13           55         101
# unique           1            1         1          1            1           1
# top              ○            ○         ○          ○            ○           ○
# freq            36          107        20         13           55         101
# mean           NaN          NaN       NaN        NaN          NaN         NaN
# std            NaN          NaN       NaN        NaN          NaN         NaN
# min            NaN          NaN       NaN        NaN          NaN         NaN
# 25%            NaN          NaN       NaN        NaN          NaN         NaN
# 50%            NaN          NaN       NaN        NaN          NaN         NaN
# 75%            NaN          NaN       NaN        NaN          NaN         NaN
# max            NaN          NaN       NaN        NaN          NaN         NaN
#
#        rs_s_kdate2 rs_s_kdate3 rs_s_parking rs_s_zoki rs_s_m_ari rs_s_m_nashi  \
# count         1670          61          100        27         19           46
# unique           1           1            1         1          1            1
# top              ○           ○            ○         ○          ○            ○
# freq          1670          61          100        27         19           46
# mean           NaN         NaN          NaN       NaN        NaN          NaN
# std            NaN         NaN          NaN       NaN        NaN          NaN
# min            NaN         NaN          NaN       NaN        NaN          NaN
# 25%            NaN         NaN          NaN       NaN        NaN          NaN
# 50%            NaN         NaN          NaN       NaN        NaN          NaN
# 75%            NaN         NaN          NaN       NaN        NaN          NaN
# max            NaN         NaN          NaN       NaN        NaN          NaN
#
#        rs_s_tahata rs_n_kdate2 rs_n_kdate3 rs_n_parking rs_n_zoki rs_n_m_ari  \
# count           94        1645          43          119        20         11
# unique           1           1           1            1         1          1
# top              ○           ○           ○            ○         ○          ○
# freq            94        1645          43          119        20         11
# mean           NaN         NaN         NaN          NaN       NaN        NaN
# std            NaN         NaN         NaN          NaN       NaN        NaN
# min            NaN         NaN         NaN          NaN       NaN        NaN
# 25%            NaN         NaN         NaN          NaN       NaN        NaN
# 50%            NaN         NaN         NaN          NaN       NaN        NaN
# 75%            NaN         NaN         NaN          NaN       NaN        NaN
# max            NaN         NaN         NaN          NaN       NaN        NaN
#
#        rs_n_m_nashi rs_n_tahata rosen_nm1 eki_nm1 bas_toho1   eki_kyori1  \
# count            55         107      2781    2781      2781  2781.000000
# unique            1           1        27     204         3          NaN
# top               ○           ○    東武伊勢崎線      八潮        徒歩          NaN
# freq             55         107       377      78      2203          NaN
# mean            NaN         NaN       NaN     NaN       NaN    15.227976
# std             NaN         NaN       NaN     NaN       NaN     7.234546
# min             NaN         NaN       NaN     NaN       NaN     1.000000
# 25%             NaN         NaN       NaN     NaN       NaN    10.000000
# 50%             NaN         NaN       NaN     NaN       NaN    14.000000
# 75%             NaN         NaN       NaN     NaN       NaN    19.000000
# max             NaN         NaN       NaN     NaN       NaN    90.000000
#
#        bastei_nm1      teiho1 rosen_nm2 eki_nm2 bas_toho2  eki_kyori2  \
# count         105  553.000000        76      76       260   76.000000
# unique         95         NaN        16      56         3         NaN
# top      ニュータウン中央         NaN     東武東上線      草加        徒歩         NaN
# freq            2         NaN        12       6       168         NaN
# mean          NaN    4.676311       NaN     NaN       NaN   13.236842
# std           NaN    3.094250       NaN     NaN       NaN    6.669070
# min           NaN    1.000000       NaN     NaN       NaN    0.000000
# 25%           NaN    2.000000       NaN     NaN       NaN    8.750000
# 50%           NaN    4.000000       NaN     NaN       NaN   14.000000
# 75%           NaN    6.000000       NaN     NaN       NaN   17.250000
# max           NaN   28.000000       NaN     NaN       NaN   34.000000
#
#        bastei_nm2     teiho2
# count          35  35.000000
# unique         35        NaN
# top        南小学校入口        NaN
# freq            1        NaN
# mean          NaN   3.885714
# std           NaN   1.921571
# min           NaN   1.000000
# 25%           NaN   3.000000
# 50%           NaN   3.000000
# 75%           NaN   5.000000
# max           NaN   9.000000

# %%
df = train_genba.describe(include='all')
df = df.loc[:,df.loc["unique",:]<=2]
print(len(df))
unique_column_name = df.columns
for c in unique_column_name:
    print("{}:{}".format(c,unique_genba[c].unique()))
# dictionary = train_genba[unique_column_name].to_dict()
# pprint.pprint(dictionary)
# Out:
# 11
# yoto1:['工業地域' '第一種低層住居専用地域' '第一種住居地域' '指定のない区域' '第一種中高層住居専用地域' '第二種中高層住居専用地域'
#  '近隣商業地域' '第二種低層住居専用地域' '準住居地域' '準工業地域' '第二種住居地域' '商業地域']
# yoto2:[nan '第一種住居地域' '第二種住居地域' '第二種中高層住居専用地域' '第一種中高層住居専用地域' '準工業地域'
#  '第一種低層住居専用地域' '第二種低層住居専用地域' '近隣商業地域' '準住居地域']
# josui:['公営' '私営']
# gesui:['公共下水' '個別浄化槽']
# gas:['個別プロパン' '都市ガス' '集中プロパン']
# usui:['宅内処理' '公共下水' '側溝']
# road1_hk:['北' '北西' '東' '南' '南西' '西' '南東' '北東' '東南']
# road1_sb:['私道' '公道' '法定外']
# road2_hk:['東' nan '北' '北東' '南東' '西' '南' '北西' '南西']
# road2_sb:['私道' nan '公道' '法定外']
# road3_hk:[nan '西' '南' '東' '北東' '南東' '北' '南西' '北西']
# road3_sb:[nan '公道' '私道' '法定外']
# road4_hk:[nan '南' '東' '北' '西' '北西' '南西' '南東']
# road4_sb:[nan '公道' '私道']
# kaoku_um:['（無）' '（有）']
# yheki_umu:['（無）' '（有）']
# yheki_yohi:['（不要）' '（要）']
# kborjs:['実測' '公簿' '公募']
# hw_status:['更地' '建物有' '造成上り' '山林' 'その他' '田・畑' '雑木林・竹林']
# toshikuiki1:['市街化区域' '市街化調整区域' '非線引き区域' '都市計画区域外']
# toshikuiki2:[nan '市街化区域' '準都市計画区域' '市街化調整区域']
# kodochiku:['第2種' '指定無' '第1種' 'その他' '第4種' '第3種']
# chikukeikaku:['（無）' '（有）']
# keikakuroad:['（無）' '（有）']
# kaihatsukyoka:['（不要）' '（要）']
# t53kyoka:['（不要）' '（要）']
# hokakyoka:['（不要）' '（要）']
# bokachiiki:['防火指定無' '22条区域' '準防火地域' 'その他' '無指定' '防火地域']
# hokakisei1:[nan '景観法' '景観地区' '国土法' '農地法' '安行出羽地区地区計画' '埋蔵文化財' '河川法' '航空法'
#  '文化財保護法（埋蔵文化財）' '自然公園法' '農地法届出要' '43条許可' '高さ最高限度有' '外壁後退' '文化財保護法'
#  '特定空港周辺特別措置法' '区画整理法' '下水道法' '風致地区' '東日本大震災復興特別区域法']
# hokakisei2:[nan '農地法' '土壌汚染対策法' '東日本震災復興特' '文化財保護法（埋蔵文化財）' '公有地拡大推進法' '景観地区' '景観法'
#  '自然公園法' '航空法' '７６条申請' '外壁後退' '高さ最高限度有' '55条許可' '区画整理法' '農地法届出要' '建築協定'
#  '埋蔵文化財' '公拡法' '都市再生特別措置法']
# hokakisei3:[nan '埋蔵文化財' '文化財保護法（埋蔵文化財）' '東日本震災復興特' '風致地区' '自然公園法' '景観法' '農地法']
# hokakisei4:[nan '公拡法' '文化財保護法（埋蔵文化財）' '風致地区']
# kinshijiko:['（無）' '（有）']
# fi4m_yohi:['（不要）' '（要）']
# fi3m_yohi:['（不要）' '（要）' '（無）']
# bus_yohi:['（不要）' '（要）']
# sho_conv:[nan '○']
# sho_super:[nan '○']
# sho_shoten:[nan '○']
# sho_market:[nan '○']
# shu_jutaku:['○' nan]
# shu_park:[nan '○']
# shu_shop:[nan '○']
# shu_factory:[nan '○']
# shu_hvline:[nan '○']
# shu_tower:[nan '○']
# shu_bochi:[nan '○']
# shu_sogi:[nan '○']
# shu_zoki:[nan '○']
# shu_kokyo:[nan '○']
# shu_highway:[nan '○']
# shu_kaido:[nan '○']
# shu_line_ari:[nan '○']
# shu_line_nashi:[nan '○']
# shu_soon:[nan '○']
# rs_e_kdate2:[nan '○']
# rs_e_kdate3:[nan '○']
# rs_e_parking:[nan '○']
# rs_e_zoki:[nan '○']
# rs_e_m_ari:[nan '○']
# rs_e_m_nashi:[nan '○']
# rs_e_tahata:[nan '○']
# rs_w_kdate2:['○' nan]
# rs_w_kdate3:[nan '○']
# rs_w_parking:[nan '○']
# rs_w_zoki:[nan '○']
# rs_w_m_ari:[nan '○']
# rs_w_m_nashi:[nan '○']
# rs_w_tahata:[nan '○']
# rs_s_kdate2:[nan '○']
# rs_s_kdate3:['○' nan]
# rs_s_parking:[nan '○']
# rs_s_zoki:[nan '○']
# rs_s_m_ari:[nan '○']
# rs_s_m_nashi:[nan '○']
# rs_s_tahata:[nan '○']
# rs_n_kdate2:[nan '○']
# rs_n_kdate3:[nan '○']
# rs_n_parking:[nan '○']
# rs_n_zoki:[nan '○']
# rs_n_m_ari:[nan '○']
# rs_n_m_nashi:[nan '○']
# rs_n_tahata:[nan '○']
# rosen_nm1:['東武東上線' 'JR川越線' '埼玉高速鉄道線' '東武伊勢崎線' 'JR武蔵野線' 'JR高崎線' '西武新宿線' '東武日光線'
#  'JR京浜東北線' '秩父鉄道秩父本線' '西武池袋線' '東武野田線' 'JR東北本線【宇都宮線】' '首都圏新都市鉄道つくばエクスプレス'
#  '埼玉新都市交通伊奈線【ニューシャトル】' 'JR湘南新宿ライン' '日暮里・舎人ライナー' 'JR埼京線' 'JR八高線(八王子～高麗川)'
#  '東武越生線' '西武豊島線' '西武秩父線' 'JR常磐線(上野～取手)' '西武狭山線' 'JR八高線(高麗川～高崎)' '東京メトロ南北線'
#  '都営三田線']
# eki_nm1:['朝霞台' '的場' '新井宿' '獨協大学前駅〈草加松原〉' '新座' '桶川' '東浦和' '上尾' '狭山市' '東武動物公園' '新所沢'
#  '西川口' '花崎' '航空公園' '石原' 'ふじみ野' '鶴ヶ島' '新田' '清瀬' '南桜井' '飯能' '行田' '上福岡'
#  'みずほ台' '西所沢' '白岡' '北浦和' '霞ヶ関' '和戸' '大宮' '三郷' '入曽' '八潮' '岩槻' '久喜' '深谷'
#  '東所沢' '狭山ヶ丘' '吉野原' '春日部' '幸手' '武蔵藤沢' '大袋' '宇須土呂' '鳩ヶ谷' '秋津' '七里' '東鷲宮'
#  '本庄' '見沼代親水公園' '藤の牛島' '内宿' '北越谷' '鳩ケ谷' '草加' '吉川' '北本' 'せんげん台' '蕨' '北坂戸'
#  '籠原' '高麗川' '八木崎' '伊奈中央' '大和田' '川越' '竹ノ塚' '所沢' '浦和美園' 'ひばりが丘' '日進' '越谷'
#  '指扇' '与野本町' '三郷中央' '北戸田' '西浦和' '若葉' '南鳩ヶ谷' '南古谷' '高坂' 'さいたま新都心' '戸塚安行'
#  '谷塚' '新河岸' '元加治' '姫宮' '蒲生' '鴻巣' '今羽' '北春日部' '一ノ割' '越谷レイクタウン' '鶴瀬' '柳瀬川'
#  '南与野' '東川口' '新秋津' '西大宮' '坂戸' '西川越' '川角' '蓮田' '戸田公園' '加須' '神保原' '東飯能' '朝霞'
#  '志木' '小手指' '浦和' '熊谷' '南大塚' '川口' '豊春' 'ひばりヶ丘' '南浦和' '栗橋' '大泉学園' '手直し'
#  '南越谷' '武蔵高萩' '北上尾' '志久' '南栗橋' '新古河' '羽貫' '東大宮' '本川越' '成増' '川口元郷' '六町'
#  '仏子' '笠幡' '新三郷' '鷲宮' '東久留米' '和光市' '戸田' '川越市' '東岩槻' '宮原' '一本松' '東松山' '金町'
#  'つきのわ' '金子' '下山口' '吉川美南' '原市' '松原団地' '武蔵浦和' '東行田' '入間市' '吹上' '根岸線蕨' '鶴ケ島'
#  '新狭山' '与野' '北大宮' '杉戸高野台' '児玉' '沼南' '新越谷' '土呂' '武里' '宇須蓮田' '武州長瀬' '武蔵嵐山'
#  '北与野' '鉄道博物館' '男衾' '武州唐沢' '東毛呂' '中浦和' '新白岡' '東宮原' 'ひばりケ丘' '行田市' '丸山'
#  '舎人公園' '北朝霞' '寄居' '北鴻巣' '獨協大学前' '大宮公園' '愛宕' '稲荷山公園' '西武球場前' '岡部' '宇須久喜'
#  '武川' '松戸' '森林公園' '舎人' '入間' '加茂宮' '綾瀬' '羽生' '古河' '丹荘' '保谷' '西高島平' '小前田']
# bas_toho1:['徒歩' 'バス' '車']
# bastei_nm1:[nan 'ふじみ野高校前' '鷹野小学校前' '西中' '東瀬ヶ崎' '網代橋' '原山3丁目' 'わかば公園入口' '上根橋' '鷹野二丁目'
#  'バイパス口' '西新宿' '白子向山' '弥栄３丁目' '都民農園' '戸ケ崎十字路' '市営住宅' '笹目' 'しらかば通り' '市民病院前'
#  '西倉松' '木曽呂南' '新郷支所' '平沼郵便局前' '浦和パークハイツ' '下富' '井戸窪' 'バイパス入口' '南山梨'
#  '美笹支所バス' '広瀬病院前' '綾瀬通り' '天王橋南' '上馬場' '大正橋' '戸ヶ崎小学校入口' '村国入口' '上町'
#  '八潮消防署前' '二ツ宮' '東明寺橋' '長栄南' '騎西２丁目' '西武フラワーヒル' '川富' '三芳小学校' '栄町' '上広瀬'
#  '柳島' 'ニュータウン中央' '円明院入口' '大泉風致地区' '西中野' '領家消防署前' '両新田' '広ヶ谷戸' '草加西高校入口'
#  '住宅展示場前' '下宗岡4丁目' '椿山' 'バス便なし' '国際興業バス・東浦８' '高須大入' '浮塚' '潮止南' '白鍬バス'
#  '松伏町役場前' '木曽根' '三橋２丁目' '八幡中学校入口' '自然公園' '中並木' '上平支所前' 'かすみ野' '大沼三丁目' '鴨田'
#  '鷹野文化センター' '草加園' '下笹目' '南団地南' '木崎中学校' '東下木崎' '彦沢１丁目南' 'ぶしニュータウン南' '病院入口'
#  '川鶴東' '丸ヶ崎火の見下' '昭和橋' '山崎' '大谷小学校前' '日生団地' '八丁' '小河原' '内前野' '新栄' '雪見ヶ原']
# rosen_nm2:[nan '東武伊勢崎線' '東武東上線' '埼玉高速鉄道線' 'JR埼京線' '西武池袋線' 'JR高崎線' 'JR武蔵野線'
#  'JR東北本線【宇都宮線】' 'JR京浜東北線' '東武野田線' '埼玉新都市交通伊奈線【ニューシャトル】' 'JR川越線' '都営三田線'
#  '東武日光線' 'JR常磐線(上野～取手)' '秩父鉄道秩父本線']
# eki_nm2:[nan '大袋' '坂戸' '浦和美園' '戸田' '稲荷山公園' '川越' '草加' '成増' '北本' '南越谷' '蓮田' '飯能'
#  '越谷レイクタウン' 'さいたま新都心' '東川口' '若葉' '新白岡' '大宮' '藤の牛島' '東浦和' '鉄道博物館' '西所沢'
#  '秋津' '朝霞台' '新越谷' 'せんげん台' '南浦和' '指扇' '加須' '西高島平' 'みずほ台' '浦和' '上尾' '杉戸高野台'
#  '的場' '鶴瀬' '川口' '金町' '北春日部' '北上尾' '七里' '志木' '幸手' '武蔵浦和' '熊谷' '東岩槻' '上福岡'
#  '羽生' '狭山ヶ丘' '所沢' 'ふじみ野' '原市' '八木崎' '宮原' '北大宮' '栗橋']
# bas_toho2:[nan '徒歩' 'バス' '車']
# bastei_nm2:[nan '旭町' '手代中央公園入口' '南小学校入口' '宿上' '市営住宅' 'レイクタウン北' '上木崎' '法乗院下' 'バイパス入口'
#  '下片山' '緑町五丁目' '中野林南' '椿山' '騎西２丁目' '柳島' '西城沼公園' 'アッピーランド入口' '大門小学校入口'
#  '市民体育館前' '前谷住宅' '弥平町' '高須大入' '高木' '緑町一丁目' '美笹支所入口' '堤公園入口' '志木市役所前'
#  '滝二丁目' '道場前' '馬込' 'エイトアリーナ入口' '水天宮' '加治橋' 'しらかば通り' '四季彩館前']
