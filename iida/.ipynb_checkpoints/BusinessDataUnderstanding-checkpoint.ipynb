# %% [markdown]
# # 飯田産業　土地の販売価格の推定
# ## 概略
# - 主催者：株式会社飯田産業
# - 目的：人材発掘
# - タスク：埼玉県における過去の土地の販売実績データを用いて土地の販売価格を予測。
# - 賞金：１位以下１００万、７０万、３０万円。
# - 注意事項
#     - 採用又は業務委託に関する情報提供又はオファーに関する連絡が来る可能性有。
# - URL:https://signate.jp/competitions/162
#
# ## 株式会社飯田産業とは
# 日本の不動産会社で、飯田グループホールディングス株式会社の完全子会社。
# 首都圏を中心に、一戸建て住宅・マンションの建設を手掛ける。大手パワービルダーの一つ。
#
# ## ルールと参加規約
# - チームでの参加は不可
# - 配布するデータ以外のデータを用いてモデルを学習することは禁止（！）
#     - 関連するデータ探しをしなくてよい！！！
# - モデルの学習に利用するツールは、オープンかつ無料なもの(?)
#     - GPL汚染とか大丈夫なの？
# - 以下のように前処理、学習、予測の３つに分け、それぞれを実行すれば処理が進むように実装する。
#     1. preprocess
#     提供データを読み込み、データに前処理を施し、モデルに入力が可能な状態でファイル出力するモジュール。
#     get_train_dataやget_test_dataのように、学習用と評価用を分けて前処理を行う関数を定義。
#     ※渡す情報として学習用データと評価用データを混在させてもよい。ただし、get_train_dataで返す結果は、
#     前処理された学習用データ、get_test_dataで返す結果は前処理された評価用データのように、処理の内容は独立させる。
#     ↑どゆこと？
#
#     2. train
#     ①で作成したファイルを読み込み、モデルを学習するモジュール。
#     学習済モデルや特徴量、クロスバリデーションの評価結果を出力する関数等を定義。
#
#     3. predict
#     ①で作成したテストデータ及び②で作成したモデルを読み込み、予測結果をファイルとして出力するモジュール。
#
# - うちの会社に提出物の全権利を渡してください。
# - 入省後質疑応答期間があるけどそこで満足行く回答をしなかったら入賞取り消しで。
# - コンペ終了後全データ削除してください。
#
# ## タスク詳細
# - データは「現場」「号棟」の2種類に分かれている。
# - 「現場」データには、"PJ番号"で管理される区画毎に土地の情報が記録されている。
# - 「号棟」データには、「現場」データで管理される区画に対して、1つ以上の号棟が割り当てられる。
# - 「号棟」単位の販売価格を予測する。
#
# <img src="./image/goto.png">
#
# ## データセットの内容
# |ファイル名|データ名|種別|レコード数|説明|
# |:---:|:---:|:---:|:---:|:---:|
# |train_genba.tsv|現場データ|学習用|2782|土地の情報|
# |train_goto.tsv|号棟データ|学習用|6462|現場データで管理される区画に対して割り当てられた号棟の情報|
# |test_genba.tsv|現場データ|評価用|1856|土地の情報|
# |test_goto.tsv|号棟データ|評価用|4274|現場データで管理される区画に対して割り当てられた号棟の情報|
# |data_definition.txt|データ定義書|資料|x|データの項目名と説明をまとめたファイル。※入力時の不備により、現場データ、号棟データには本定義書で定義されていない値が入っている|
# |sample_submit.tsv|応募用サンプルファイル|資料|x|1列目に"id"を、2列目に"id"に対応する、予測した"keiyaku_pr"を記入したファイルを、ヘッダ無しtsv形式で投稿する。|
#
# ### データ定義書(data definition.txt)

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 200)
data_definition = pd.read_csv('dataset/data_definition.txt', delimiter='\t')
print(data_definition[["項目名","データ種別","項目名（日本語）","データ型"]])
# Out:
#                  項目名 データ種別           項目名（日本語）  データ型
# 0              pj_no    現場               PJ番号    数値
# 1              jukyo    現場               住居表示  テキスト
# 2      chiseki_js_hb    現場        地積 (実測)(平米）    数値
# 3      chiseki_kb_hb    現場        地積 (公簿)(平米）    数値
# 4              yoto1    現場              用途地域1  カテゴリ
# 5              yoto2    現場              用途地域2  カテゴリ
# 6            kempei1    現場              建ぺい率1    数値
# 7            kempei2    現場              建ぺい率2    数値
# 8            yoseki1    現場               容積率1    数値
# 9            yoseki2    現場               容積率2    数値
# 10             josui    現場             設備(上水)  カテゴリ
# 11             gesui    現場             設備(下水)  カテゴリ
# 12               gas    現場             設備(ガス)  カテゴリ
# 13              usui    現場             設備(雨水)  カテゴリ
# 14        tateuri_su    現場           販売種別(建売)    数値
# 15       tochiuri_su    現場         販売種別(土地売り)    数値
# 16          joken_su    現場        販売種別(条件付売地)    数値
# 17      hy1f_date_su    現場          販売予定(平屋建)    数値
# 18      hy2f_date_su    現場          販売予定(2階建)    数値
# 19      hy3f_date_su    現場          販売予定(3階建)    数値
# 20          road1_hk    現場              道路方角1  カテゴリ
# 21          road1_sb    現場              道路種別1  カテゴリ
# 22          road1_fi    現場              道路幅員1    数値
# 23          road1_mg    現場              道路間口1    数値
# 24          road2_hk    現場              道路方角2  カテゴリ
# 25          road2_sb    現場              道路種別2  カテゴリ
# 26          road2_fi    現場              道路幅員2    数値
# 27          road2_mg    現場              道路間口2    数値
# 28          road3_hk    現場              道路方角3  カテゴリ
# 29          road3_sb    現場              道路種別3  カテゴリ
# 30          road3_fi    現場              道路幅員3    数値
# 31          road3_mg    現場              道路間口3    数値
# 32          road4_hk    現場              道路方角4  カテゴリ
# 33          road4_sb    現場              道路種別4  カテゴリ
# 34          road4_fi    現場              道路幅員4    数値
# 35          road4_mg    現場              道路間口4    数値
# 36          kaoku_um    現場               家屋現況    2値
# 37          kaoku_hb    現場           家屋面積(平米)    数値
# 38       yheki_kotei    現場  高低差現況宅盤と道/隣の最大高低差    数値
# 39         yheki_umu    現場            高低差既存擁壁    2値
# 40        yheki_yohi    現場            高低差新設擁壁    2値
# 41      gk_sho_kyori    現場              小学校距離    数値
# 42      gk_chu_kyori    現場              中学校距離    数値
# 43            kborjs    現場               取引形態    2値
# 44         hw_status    現場              引渡の状態  カテゴリ
# 45       toshikuiki1    現場           都市計画区域別1  カテゴリ
# 46       toshikuiki2    現場           都市計画区域別2  カテゴリ
# 47         kodochiku    現場               高度地区  カテゴリ
# 48      chikukeikaku    現場               地区計画    2値
# 49       keikakuroad    現場               計画道路    2値
# 50     kaihatsukyoka    現場               開発許可    2値
# 51          t53kyoka    現場             ５３条の許可    2値
# 52         hokakyoka    現場             その他許認可    2値
# 53        bokachiiki    現場               防火指定  カテゴリ
# 54        minmenseki    現場             最低敷地面積    数値
# 55        hokakisei1    現場             その他規制①  テキスト
# 56        hokakisei2    現場             その他規制②  テキスト
# 57        hokakisei3    現場             その他規制③  テキスト
# 58        hokakisei4    現場             その他規制④  テキスト
# 59        kinshijiko    現場        仕入禁止事項との抵触等  カテゴリ
# 60        rosenka_hb    現場           路線価格(平米)    数値
# 61           koji_hb    現場           公示地価(平米)    数値
# 62          kijun_hb    現場           基準地価(平米)    数値
# 63       mseki_yt_hb    現場         有効宅地面積(平米)    数値
# 64       mseki_rd_hb    現場       道路（SB含む）(平米)    数値
# 65       mseki_dp_hb    現場       ゴミ置場・公園等(平米)    数値
# 66   tc_mseki_min_hb    現場         土地最小面積(平米)    数値
# 67   tc_mseki_max_hb    現場         土地最大面積(平米)    数値
# 68   tt_mseki_min_hb    現場         建物最小面積(平米)    数値
# 69   tt_mseki_max_hb    現場         建物最大面積(平米)    数値
# 70   tc_mseki_avg_hb    現場         土地平均面積(平米)    数値
# 71   tt_mseki_avg_hb    現場         建物平均面積(平米)    数値
# 72         fi4m_yohi    現場        幅員4m未満道路の通過    2値
# 73         fi3m_yohi    現場        幅員3m未満道路の通過    2値
# 74        fi4m_kyori    現場  幅員3m以上4m未満道路の通過距離    数値
# 75        fi3m_kyori    現場      幅員3m未満道路の通過距離    数値
# 76          bus_yohi    現場               バス要否    2値
# 77           bus_hon    現場        平日１日のバス運行本数    数値
# 78          sho_conv    現場               コンビニ    2値
# 79         sho_super    現場               スーパー    2値
# 80        sho_shoten    現場                商店街    2値
# 81        sho_market    現場             大型商業施設    2値
# 82        shu_jutaku    現場                住宅地    2値
# 83          shu_park    現場               公園隣接    2値
# 84          shu_shop    現場               商店隣接    2値
# 85       shu_factory    現場               工場隣接    2値
# 86        shu_hvline    現場               高圧線下    2値
# 87         shu_tower    現場                鉄塔横    2値
# 88         shu_bochi    現場               墓地隣接    2値
# 89          shu_sogi    現場              葬儀場隣接    2値
# 90          shu_zoki    現場              雑木林隣接    2値
# 91         shu_kokyo    現場             公共施設隣接    2値
# 92       shu_highway    現場             高速道路沿い    2値
# 93         shu_kaido    現場               街道隣接    2値
# 94      shu_line_ari    現場     線路沿い/近い(騒音影響有)    2値
# 95    shu_line_nashi    現場     線路沿い/近い(騒音影響無)    2値
# 96          shu_soon    現場             その他騒音有    2値
# 97         gk_yoc_tm    現場              幼稚園徒歩    数値
# 98         gk_sho_tm    現場              小学校徒歩    数値
# 99         gk_chu_tm    現場              中学校徒歩    数値
# 100      rs_e_kdate2    現場      隣接物件東戸建（2F以下）    2値
# 101      rs_e_kdate3    現場      隣接物件東戸建（3F以上）    2値
# 102     rs_e_parking    現場           隣接物件東駐車場    2値
# 103        rs_e_zoki    現場           隣接物件東雑木林    2値
# 104       rs_e_m_ari    現場    隣接物件東マンション（影響有）    2値
# 105     rs_e_m_nashi    現場    隣接物件東マンション（影響無）    2値
# 106      rs_e_tahata    現場            隣接物件東田畑    2値
# 107      rs_w_kdate2    現場      隣接物件西戸建（2F以下）    2値
# 108      rs_w_kdate3    現場      隣接物件西戸建（3F以上）    2値
# 109     rs_w_parking    現場           隣接物件西駐車場    2値
# 110        rs_w_zoki    現場           隣接物件西雑木林    2値
# 111       rs_w_m_ari    現場    隣接物件西マンション（影響有）    2値
# 112     rs_w_m_nashi    現場    隣接物件西マンション（影響無）    2値
# 113      rs_w_tahata    現場            隣接物件西田畑    2値
# 114      rs_s_kdate2    現場      隣接物件南戸建（2F以下）    2値
# 115      rs_s_kdate3    現場      隣接物件南戸建（3F以上）    2値
# 116     rs_s_parking    現場           隣接物件南駐車場    2値
# 117        rs_s_zoki    現場           隣接物件南雑木林    2値
# 118       rs_s_m_ari    現場    隣接物件南マンション（影響有）    2値
# 119     rs_s_m_nashi    現場    隣接物件南マンション（影響無）    2値
# 120      rs_s_tahata    現場            隣接物件南田畑    2値
# 121      rs_n_kdate2    現場      隣接物件北戸建（2F以下）    2値
# 122      rs_n_kdate3    現場      隣接物件北戸建（3F以上）    2値
# 123     rs_n_parking    現場           隣接物件北駐車場    2値
# 124        rs_n_zoki    現場           隣接物件北雑木林    2値
# 125       rs_n_m_ari    現場    隣接物件北マンション（影響有）    2値
# 126     rs_n_m_nashi    現場    隣接物件北マンション（影響無）    2値
# 127      rs_n_tahata    現場            隣接物件北田畑    2値
# 128        rosen_nm1    現場                路線1  テキスト
# 129          eki_nm1    現場                 駅1  テキスト
# 130        bas_toho1    現場              バス徒歩1  カテゴリ
# 131       eki_kyori1    現場               駅距離1    数値
# 132       bastei_nm1    現場               バス停1  テキスト
# 133           teiho1    現場             バス停徒歩1    数値
# 134        rosen_nm2    現場                路線2  テキスト
# 135          eki_nm2    現場                 駅2  テキスト
# 136        bas_toho2    現場              バス徒歩2  カテゴリ
# 137       eki_kyori2    現場               駅距離2    数値
# 138       bastei_nm2    現場               バス停2  テキスト
# 139           teiho2    現場             バス停徒歩2    数値
# 140            pj_no    号棟               PJ番号    数値
# 141       keiyaku_pr    号棟               契約金額    数値
# 142         tc_mseki    号棟               土地面積    数値
# 143         tt_mseki    号棟               建物面積    数値
# 144        levelplan    号棟             階数・プラン  カテゴリ
# 145           fukuin    号棟              幅員〔m〕    数値
# 146          road_st    号棟               道路状況  カテゴリ
# 147         magutchi    号棟              間口〔m〕    数値
# 148       setsudo_hi    号棟               接道方位  カテゴリ
# 149       setsudo_kj    号棟               接道形状  カテゴリ
# 150           jigata    号棟                 地型  カテゴリ
# 151          hiatari    号棟               日当たり  カテゴリ
# 152         niwasaki    号棟              庭先〔m〕    数値
# 153           garage    号棟              車庫〔台〕    数値
# 154         kobetsu1    号棟              個別要因①  カテゴリ
# 155         kobetsu2    号棟              個別要因②  カテゴリ
# 156         kobetsu3    号棟              個別要因③  カテゴリ
# 157         kobetsu4    号棟              個別要因④  カテゴリ

# %%
print(data_definition[["項目名","説明"]])
# Out:
#                  項目名                                                 説明
# 0              pj_no                        プロジェクト番号。現場データと号棟データの紐付けキー。
# 1              jukyo                                         住所（市区町村まで）
# 2      chiseki_js_hb                                           地積㎡数(実測)
# 3      chiseki_kb_hb                                           地積㎡数(公簿)
# 4              yoto1  「第一種低層住居専用地域・第二種低層住居専用地域・第一種中高層住居専用地域・第二種中高層住居...
# 5              yoto2  「第一種低層住居専用地域・第二種低層住居専用地域・第一種中高層住居専用地域・第二種中高層住居...
# 6            kempei1                                      用途地域1に対する建ぺい率
# 7            kempei2                                      用途地域2に対する建ぺい率
# 8            yoseki1                                       用途地域1に対する容積率
# 9            yoseki2                                       用途地域2に対する容積率
# 10             josui                                         「公営・私営・井戸」
# 11             gesui                             「公共下水・個別浄化槽・集中浄化槽・汲取式」
# 12               gas                               「都市ガス・個別プロパン・集中プロパン」
# 13              usui                                  「宅内処理・公共下水・側溝・水路」
# 14        tateuri_su                                              建売の棟数
# 15       tochiuri_su                                           土地売りの区画数
# 16          joken_su                                          条件付売地の区画数
# 17      hy1f_date_su                                             平屋建の棟数
# 18      hy2f_date_su                                             2階建の棟数
# 19      hy3f_date_su                                             3階建の棟数
# 20          road1_hk        「東・西・南・北・北東・北西・南東・南西」 1つの土地が、どの方角に接しているかを表記
# 21          road1_sb                              「公道・私道・法定外」 ※道路方角1に対応
# 22          road1_fi                                     道路幅員 ※道路方角1に対応
# 23          road1_mg                                     道路間口 ※道路方角1に対応
# 24          road2_hk                              「東・西・南・北・北東・北西・南東・南西」
# 25          road2_sb                              「公道・私道・法定外」 ※道路方角2に対応
# 26          road2_fi                                     道路幅員 ※道路方角2に対応
# 27          road2_mg                                     道路間口 ※道路方角2に対応
# 28          road3_hk                              「東・西・南・北・北東・北西・南東・南西」
# 29          road3_sb                              「公道・私道・法定外」 ※道路方角3に対応
# 30          road3_fi                                     道路幅員 ※道路方角3に対応
# 31          road3_mg                                     道路間口 ※道路方角3に対応
# 32          road4_hk                              「東・西・南・北・北東・北西・南東・南西」
# 33          road4_sb                              「公道・私道・法定外」 ※道路方角4に対応
# 34          road4_fi                                     道路幅員 ※道路方角4に対応
# 35          road4_mg                                     道路間口 ※道路方角4に対応
# 36          kaoku_um                                          「(有)・(無)」
# 37          kaoku_hb                                             家屋面積㎡数
# 38       yheki_kotei                                    宅盤と道路含む隣地の最大高低差
# 39         yheki_umu                                          「(有)・(無)」
# 40        yheki_yohi                                         「(要)・(不要)」
# 41      gk_sho_kyori                                              小学校距離
# 42      gk_chu_kyori                                              中学校距離
# 43            kborjs                                            「公簿・実測」
# 44         hw_status                    「更地・造成上り・建物有・山林・田・畑・雑木林・竹林・その他」
# 45       toshikuiki1  「市街化区域・市街化調整区域・非線引き区域・準都市計画区域・都市計画区域外」 ※2つの都市計...
# 46       toshikuiki2  「市街化区域・市街化調整区域・非線引き区域・準都市計画区域・都市計画区域外」 ※2つの都市計...
# 47         kodochiku          「第1種・第2種・第3種・第4種・第5種・第6種・第7種・第8種・指定無・その他」
# 48      chikukeikaku                                          「(有)・(無)」
# 49       keikakuroad                                          「(有)・(無)」
# 50     kaihatsukyoka                                         「(要)・(不要)」
# 51          t53kyoka                                         「(要)・(不要)」
# 52         hokakyoka                                         「(要)・(不要)」
# 53        bokachiiki                       「防火地域・準防火地域・22条区域・防火指定無・その他」
# 54        minmenseki                                             最低敷地面積
# 55        hokakisei1                               その他規制　※複数ある場合は①～④を利用
# 56        hokakisei2                               その他規制　※複数ある場合は①～④を利用
# 57        hokakisei3                               その他規制　※複数ある場合は①～④を利用
# 58        hokakisei4                               その他規制　※複数ある場合は①～④を利用
# 59        kinshijiko                                          「(有)・(無)」
# 60        rosenka_hb                                         路線価格㎡単価を収録
# 61           koji_hb                                         公示地価㎡単価を収録
# 62          kijun_hb                                         基準地価㎡単価を収録
# 63       mseki_yt_hb                                           有効宅地面積㎡数
# 64       mseki_rd_hb                                    セットバックを含む道路面積㎡数
# 65       mseki_dp_hb                                     ゴミ置き場・公園等の面積㎡数
# 66   tc_mseki_min_hb                                           土地最小面積㎡数
# 67   tc_mseki_max_hb                                           土地最大面積㎡数
# 68   tt_mseki_min_hb                                           建物最小面積㎡数
# 69   tt_mseki_max_hb                                           建物最大面積㎡数
# 70   tc_mseki_avg_hb                                           土地平均面積㎡数
# 71   tt_mseki_avg_hb                                           建物平均面積㎡数
# 72         fi4m_yohi                                         「(要)・(不要)」
# 73         fi3m_yohi                                         「(要)・(不要)」
# 74        fi4m_kyori                                  幅員3m以上4m未満道路の通過距離
# 75        fi3m_kyori                                      幅員3m未満道路の通過距離
# 76          bus_yohi                                         「(要)・(不要)」
# 77           bus_hon                                        平日１日のバス運行本数
# 78          sho_conv                                     徒歩5分圏内にある場合「○」
# 79         sho_super                                     徒歩5分圏内にある場合「○」
# 80        sho_shoten                                     徒歩5分圏内にある場合「○」
# 81        sho_market                                     徒歩5分圏内にある場合「○」
# 82        shu_jutaku                                          該当する場合「○」
# 83          shu_park                                          該当する場合「○」
# 84          shu_shop                                          該当する場合「○」
# 85       shu_factory                                          該当する場合「○」
# 86        shu_hvline                                          該当する場合「○」
# 87         shu_tower                                          該当する場合「○」
# 88         shu_bochi                                          該当する場合「○」
# 89          shu_sogi                                          該当する場合「○」
# 90          shu_zoki                                          該当する場合「○」
# 91         shu_kokyo                                          該当する場合「○」
# 92       shu_highway                                          該当する場合「○」
# 93         shu_kaido                                          該当する場合「○」
# 94      shu_line_ari                                          該当する場合「○」
# 95    shu_line_nashi                                          該当する場合「○」
# 96          shu_soon                                          該当する場合「○」
# 97         gk_yoc_tm                                         幼稚園までの徒歩時間
# 98         gk_sho_tm                                         小学校までの徒歩時間
# 99         gk_chu_tm                                         中学校までの徒歩時間
# 100      rs_e_kdate2                                          該当する場合「○」
# 101      rs_e_kdate3                                          該当する場合「○」
# 102     rs_e_parking                                          該当する場合「○」
# 103        rs_e_zoki                                          該当する場合「○」
# 104       rs_e_m_ari                        該当する場合「○」 ※宅地にマンションの影がかかる場合
# 105     rs_e_m_nashi                                          該当する場合「○」
# 106      rs_e_tahata                                          該当する場合「○」
# 107      rs_w_kdate2                                          該当する場合「○」
# 108      rs_w_kdate3                                          該当する場合「○」
# 109     rs_w_parking                                          該当する場合「○」
# 110        rs_w_zoki                                          該当する場合「○」
# 111       rs_w_m_ari                        該当する場合「○」 ※宅地にマンションの影がかかる場合
# 112     rs_w_m_nashi                                          該当する場合「○」
# 113      rs_w_tahata                                          該当する場合「○」
# 114      rs_s_kdate2                                          該当する場合「○」
# 115      rs_s_kdate3                                          該当する場合「○」
# 116     rs_s_parking                                          該当する場合「○」
# 117        rs_s_zoki                                          該当する場合「○」
# 118       rs_s_m_ari                        該当する場合「○」 ※宅地にマンションの影がかかる場合
# 119     rs_s_m_nashi                                          該当する場合「○」
# 120      rs_s_tahata                                          該当する場合「○」
# 121      rs_n_kdate2                                          該当する場合「○」
# 122      rs_n_kdate3                                          該当する場合「○」
# 123     rs_n_parking                                          該当する場合「○」
# 124        rs_n_zoki                                          該当する場合「○」
# 125       rs_n_m_ari                        該当する場合「○」 ※宅地にマンションの影がかかる場合
# 126     rs_n_m_nashi                                          該当する場合「○」
# 127      rs_n_tahata                                          該当する場合「○」
# 128        rosen_nm1                                        主に利用する路線の名前
# 129          eki_nm1                                         主に利用する駅の名前
# 130        bas_toho1                                 駅1までの移動手段「徒歩・バス・車」
# 131       eki_kyori1                           バス徒歩1での移動による駅1までの移動時間（分）
# 132       bastei_nm1                                       主に利用するバス停の名前
# 133           teiho1                            徒歩による最寄りのバス停1までの移動時間（分）
# 134        rosen_nm2                                     サブとして利用する路線の名前
# 135          eki_nm2                                      サブとして利用する駅の名前
# 136        bas_toho2                                 駅2までの移動手段「徒歩・バス・車」
# 137       eki_kyori2                           バス徒歩2での移動による駅2までの移動時間（分）
# 138       bastei_nm2                                    サブとして利用するバス停の名前
# 139           teiho2                            徒歩による最寄りのバス停2までの移動時間（分）
# 140            pj_no                        プロジェクト番号。現場データと号棟データの紐付けキー。
# 141       keiyaku_pr                                     目的変数となる土地の販売価格
# 142         tc_mseki                                             土地面積㎡数
# 143         tt_mseki                                             建物面積㎡数
# 144        levelplan  「土地売り・1F/1LDK・1F/1LDK+S・1F/1LDK+2S・1F/2LDK・1F/...
# 145           fukuin                                         前面道路の幅員〔m〕
# 146          road_st                           「未舗装・歩道あり・歩道+緑地帯あり・問題なし」
# 147         magutchi                                         前面道路の間口〔m〕
# 148       setsudo_hi  「東・西・南・北・南東・南西・北東・北西・東＋西・東＋南・東＋北・東＋南東・東＋南西・東＋北...
# 149       setsudo_kj                                         「良い・普通・悪い」
# 150           jigata                            「整形地・敷地延長・不整形地・間口狭・奥行長」
# 151          hiatari                                         「良い・普通・悪い」
# 152         niwasaki                               庭先〔m〕　隣地（または道路）までの距離
# 153           garage                                              車庫〔台〕
# 154         kobetsu1  「高圧線下・信号近い・信号前・横断歩道前・踏切付近・ごみ置き場前・心理的瑕疵あり・計画道路・...
# 155         kobetsu2  「高圧線下・信号近い・信号前・横断歩道前・踏切付近・ごみ置き場前・心理的瑕疵あり・計画道路・...
# 156         kobetsu3  「高圧線下・信号近い・信号前・横断歩道前・踏切付近・ごみ置き場前・心理的瑕疵あり・計画道路・...
# 157         kobetsu4  「高圧線下・信号近い・信号前・横断歩道前・踏切付近・ごみ置き場前・心理的瑕疵あり・計画道路・...

# %% [markdown]
# ### 現場データ(train_genba.tsv)
# - データ定義書の140番目の項目までが現場データの変数

# %%
train_genba = pd.read_csv('dataset/train_genba.tsv', delimiter='\t')
print(train_genba.head(10))
print(train_genba.columns.tolist())
print(len(train_genba.columns.tolist()))
# Out:
#    pj_no             jukyo  chiseki_js_hb  chiseki_kb_hb         yoto1 yoto2  \
# 0      0          埼玉県朝霞市泉水         109.26         109.10          工業地域   NaN
# 1      1        埼玉県川越市大字的場         136.15         136.00   第一種低層住居専用地域   NaN
# 2      2         埼玉県川口市安行原          86.92          86.52   第一種低層住居専用地域   NaN
# 3      3          埼玉県草加市松江         164.91         164.07          工業地域   NaN
# 4      4         埼玉県新座市野火止         403.58         403.58   第一種低層住居専用地域   NaN
# 5      5   埼玉県桶川市大字上日出谷字殿山         114.44         114.55       第一種住居地域   NaN
# 6      6  埼玉県さいたま市見沼区片柳字南台         531.98         498.06       指定のない区域   NaN
# 7      7          埼玉県上尾市東町         242.78         242.78       第一種住居地域   NaN
# 8      8          埼玉県狭山市中央         224.99         224.99  第一種中高層住居専用地域   NaN
# 9      9    埼玉県北葛飾郡杉戸町大字堤根        1010.00        1002.00       指定のない区域   NaN
#
#    kempei1  kempei2  yoseki1  yoseki2   ...   bas_toho1 eki_kyori1 bastei_nm1  \
# 0       60      0.0      200      0.0   ...          徒歩         17        NaN
# 1       60      0.0      200      0.0   ...          徒歩         13        NaN
# 2       50      0.0      100      0.0   ...          徒歩         27        NaN
# 3       60      0.0      200      0.0   ...          徒歩         18        NaN
# 4       50      0.0       80      0.0   ...          徒歩          7        NaN
# 5       60      0.0      200      0.0   ...          バス          7        NaN
# 6       60      0.0      200      0.0   ...          バス         13        NaN
# 7       60      0.0      200      0.0   ...          徒歩         22        NaN
# 8       60      0.0      200      0.0   ...          バス          5        NaN
# 9       60      0.0      200      0.0   ...          徒歩         32        NaN
#
#   teiho1  rosen_nm2  eki_nm2  bas_toho2  eki_kyori2  bastei_nm2  teiho2
# 0    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 1    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 2    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 3    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 4    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 5    8.0        NaN      NaN        NaN         NaN         NaN     NaN
# 6    1.0        NaN      NaN        NaN         NaN         NaN     NaN
# 7    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 8    2.0        NaN      NaN        NaN         NaN         NaN     NaN
# 9    NaN        NaN      NaN        NaN         NaN         NaN     NaN
#
# [10 rows x 140 columns]
# ['pj_no', 'jukyo', 'chiseki_js_hb', 'chiseki_kb_hb', 'yoto1', 'yoto2', 'kempei1', 'kempei2', 'yoseki1', 'yoseki2', 'josui', 'gesui', 'gas', 'usui', 'tateuri_su', 'tochiuri_su', 'joken_su', 'hy1f_date_su', 'hy2f_date_su', 'hy3f_date_su', 'road1_hk', 'road1_sb', 'road1_fi', 'road1_mg', 'road2_hk', 'road2_sb', 'road2_fi', 'road2_mg', 'road3_hk', 'road3_sb', 'road3_fi', 'road3_mg', 'road4_hk', 'road4_sb', 'road4_fi', 'road4_mg', 'kaoku_um', 'kaoku_hb', 'yheki_kotei', 'yheki_umu', 'yheki_yohi', 'gk_sho_kyori', 'gk_chu_kyori', 'kborjs', 'hw_status', 'toshikuiki1', 'toshikuiki2', 'kodochiku', 'chikukeikaku', 'keikakuroad', 'kaihatsukyoka', 't53kyoka', 'hokakyoka', 'bokachiiki', 'minmenseki', 'hokakisei1', 'hokakisei2', 'hokakisei3', 'hokakisei4', 'kinshijiko', 'rosenka_hb', 'koji_hb', 'kijun_hb', 'mseki_yt_hb', 'mseki_rd_hb', 'mseki_dp_hb', 'tc_mseki_min_hb', 'tc_mseki_max_hb', 'tt_mseki_min_hb', 'tt_mseki_max_hb', 'tc_mseki_avg_hb', 'tt_mseki_avg_hb', 'fi4m_yohi', 'fi3m_yohi', 'fi4m_kyori', 'fi3m_kyori', 'bus_yohi', 'bus_hon', 'sho_conv', 'sho_super', 'sho_shoten', 'sho_market', 'shu_jutaku', 'shu_park', 'shu_shop', 'shu_factory', 'shu_hvline', 'shu_tower', 'shu_bochi', 'shu_sogi', 'shu_zoki', 'shu_kokyo', 'shu_highway', 'shu_kaido', 'shu_line_ari', 'shu_line_nashi', 'shu_soon', 'gk_yoc_tm', 'gk_sho_tm', 'gk_chu_tm', 'rs_e_kdate2', 'rs_e_kdate3', 'rs_e_parking', 'rs_e_zoki', 'rs_e_m_ari', 'rs_e_m_nashi', 'rs_e_tahata', 'rs_w_kdate2', 'rs_w_kdate3', 'rs_w_parking', 'rs_w_zoki', 'rs_w_m_ari', 'rs_w_m_nashi', 'rs_w_tahata', 'rs_s_kdate2', 'rs_s_kdate3', 'rs_s_parking', 'rs_s_zoki', 'rs_s_m_ari', 'rs_s_m_nashi', 'rs_s_tahata', 'rs_n_kdate2', 'rs_n_kdate3', 'rs_n_parking', 'rs_n_zoki', 'rs_n_m_ari', 'rs_n_m_nashi', 'rs_n_tahata', 'rosen_nm1', 'eki_nm1', 'bas_toho1', 'eki_kyori1', 'bastei_nm1', 'teiho1', 'rosen_nm2', 'eki_nm2', 'bas_toho2', 'eki_kyori2', 'bastei_nm2', 'teiho2']
# 140

# %% [markdown]
# ### 号棟データ(train_goto.tsv)
# - データ定義書の141番目から157番目までが号棟データの変数
# - keiyaku_prを予測する。

# %%
train_goto = pd.read_csv('dataset/train_goto.tsv', delimiter='\t')
print(train_goto.head(10))
print(train_goto.columns.tolist())
print(len(train_goto.columns.tolist()))
# Out:
#            id  pj_no  keiyaku_pr  tc_mseki  tt_mseki levelplan  fukuin  \
# 0  train_0000      0    39800000    109.26    104.43   2F/4LDK     4.0
# 1  train_0001      1    22300000    136.11    105.16   2F/4LDK     4.2
# 2  train_0002      2    19800000     87.07     85.94   2F/4LDK     4.0
# 3  train_0003      3    33990000    163.75    105.98   2F/4LDK     4.0
# 4  train_0004      4    30800000    111.51     89.01   2F/4LDK     4.0
# 5  train_0005      4    35800000    111.53     89.01   2F/4LDK     4.0
# 6  train_0006      4    35300000    111.53     88.18   2F/3LDK     4.0
# 7  train_0007      5    21496297    114.44     98.95   2F/4LDK     4.0
# 8  train_0008      6    19200000    274.25      0.00   2F/4LDK     7.1
# 9  train_0009      6    17900000    241.73      0.00   2F/4LDK     7.4
#
#   road_st  magutchi setsudo_hi setsudo_kj jigata hiatari  niwasaki  garage  \
# 0    問題なし       9.9          東         良い    整形地      普通      4.00       1
# 1    問題なし       9.3         北西         普通   不整形地      普通      3.00       1
# 2    問題なし      11.1          東         普通    整形地      普通      2.80       1
# 3    問題なし      10.5          南         普通    整形地      良い      4.00       2
# 4    問題なし      13.5          北         良い    整形地      普通      2.00       2
# 5    問題なし       7.0          南         良い    整形地      良い      2.00       2
# 6    問題なし       6.8          南         良い    整形地      良い      4.00       2
# 7    問題なし       7.8          東         普通    整形地      普通      3.19       1
# 8    問題なし      10.3         南東         良い    整形地      良い      2.65       2
# 9    問題なし       7.9      南東＋北西         良い    整形地      良い      6.84       2
#
#   kobetsu1 kobetsu2 kobetsu3 kobetsu4
# 0     床暖房付      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN
# 4     床暖房付      NaN      NaN      NaN
# 5     床暖房付      NaN      NaN      NaN
# 6     床暖房付      NaN      NaN      NaN
# 7      眺望良       角地      NaN      NaN
# 8      眺望良      NaN      NaN      NaN
# 9      眺望良    交通量多い      NaN      NaN
# ['id', 'pj_no', 'keiyaku_pr', 'tc_mseki', 'tt_mseki', 'levelplan', 'fukuin', 'road_st', 'magutchi', 'setsudo_hi', 'setsudo_kj', 'jigata', 'hiatari', 'niwasaki', 'garage', 'kobetsu1', 'kobetsu2', 'kobetsu3', 'kobetsu4']
# 19

# %% [markdown]
# ### 現場データ(test_genba.tsv)

# %%
test_genba = pd.read_csv('dataset/test_genba.tsv', delimiter='\t')
print(test_genba.head(10))
# Out:
#    pj_no          jukyo  chiseki_js_hb  chiseki_kb_hb         yoto1 yoto2  \
# 0   2781        埼玉県羽生市東         208.26         208.26   第一種低層住居専用地域   NaN
# 1   2782     埼玉県川越市大字寺尾        1369.35        1497.00   第一種低層住居専用地域   NaN
# 2   2783       埼玉県三郷市新和         110.28         110.28         準工業地域   NaN
# 3   2784       埼玉県志木市柏町         198.38         198.00  第一種中高層住居専用地域   NaN
# 4   2785  埼玉県さいたま市北区奈良町         229.45         229.45  第一種中高層住居専用地域   NaN
# 5   2786  埼玉県北足立郡伊奈町西小針        2349.39        2349.39          工業地域   NaN
# 6   2787      埼玉県草加市金明町          75.61          74.77  第一種中高層住居専用地域   NaN
# 7   2788      埼玉県春日部市豊町         133.26         133.26  第一種中高層住居専用地域   NaN
# 8   2789       埼玉県ふじみ野市         101.48         101.48       第一種住居地域   NaN
# 9   2790      埼玉県新座市野火止         825.19         825.19       第一種住居地域   NaN
#
#    kempei1  kempei2  yoseki1  yoseki2   ...   bas_toho1 eki_kyori1 bastei_nm1  \
# 0       50      NaN       80      NaN   ...          徒歩         21        NaN
# 1       50      0.0      100      0.0   ...          徒歩         11        NaN
# 2       60      NaN      200      NaN   ...          徒歩          9        NaN
# 3       60      0.0      200      0.0   ...          徒歩          9        NaN
# 4       60      0.0      200      0.0   ...          バス         13       奈良団地
# 5       60      0.0      200      0.0   ...          徒歩          9        NaN
# 6       60      0.0      200      0.0   ...          徒歩         10        NaN
# 7       60      0.0      200      0.0   ...          徒歩         21        NaN
# 8       60      0.0      200      0.0   ...          徒歩          9        NaN
# 9       60      0.0      200      0.0   ...          徒歩         20        NaN
#
#   teiho1  rosen_nm2  eki_nm2  bas_toho2  eki_kyori2  bastei_nm2  teiho2
# 0    NaN        NaN      NaN         徒歩         NaN         NaN     NaN
# 1    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 2    NaN        NaN      NaN         徒歩         NaN         NaN     NaN
# 3    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 4    2.0        NaN      NaN        NaN         NaN         NaN     NaN
# 5    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 6    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 7    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 8    NaN        NaN      NaN        NaN         NaN         NaN     NaN
# 9    NaN        NaN      NaN        NaN         NaN         NaN     NaN
#
# [10 rows x 140 columns]

# %% [markdown]
# ### 号棟データ(test_goto.tsv)
# - 予測変数keiyaku_prのみ項目がない。

# %%
test_goto = pd.read_csv('dataset/test_goto.tsv', delimiter='\t')
print(test_goto.head(10))
print(test_goto.columns.tolist())
print(len(test_goto.columns.tolist()))
# Out:
#           id  pj_no  tc_mseki  tt_mseki levelplan  fukuin road_st  magutchi  \
# 0  test_0000   2781    212.38    118.40   2F/4LDK     4.0    問題なし      13.0
# 1  test_0001   2782    100.87     97.08   2F/4LDK     4.0    問題なし       7.9
# 2  test_0002   2782    106.02     97.19   2F/4LDK     4.0    問題なし       7.1
# 3  test_0003   2782    110.15    100.60   2F/4LDK     4.0    問題なし       9.5
# 4  test_0004   2782    112.13     97.29   2F/4LDK     4.0    問題なし      14.1
# 5  test_0005   2782    110.03     97.91   2F/4LDK     4.0    問題なし       7.3
# 6  test_0006   2782    110.48     99.77   2F/4LDK     4.0    問題なし      14.4
# 7  test_0007   2782    110.25     97.92   2F/4LDK     4.0    問題なし      15.0
# 8  test_0008   2782    100.43     97.08   2F/4LDK     4.0    問題なし       7.1
# 9  test_0009   2782    120.60    101.85   2F/4LDK     4.0    問題なし      14.0
#
#   setsudo_hi setsudo_kj jigata hiatari  niwasaki  garage kobetsu1 kobetsu2  \
# 0          西         良い    整形地      良い       6.5       2  行き止まり途中      NaN
# 1          南         良い    整形地      良い       1.6       1      二方路      NaN
# 2          西         悪い    整形地      普通       2.0       1      NaN      NaN
# 3         南西         良い    整形地      良い       2.1       1       角地      二方路
# 4         北西         良い    整形地      普通       2.1       2       角地   ごみ置き場前
# 5          北         良い    整形地      悪い       1.2       1      NaN      NaN
# 6         北西         良い    整形地      普通       1.2       1       角地      NaN
# 7          北         良い    整形地      悪い       1.2       1      NaN      NaN
# 8          南         良い    整形地      良い       1.8       1      二方路      NaN
# 9         南東         良い    整形地      良い       4.2       2       角地      二方路
#
#   kobetsu3 kobetsu4
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
# 5      NaN      NaN
# 6      NaN      NaN
# 7      NaN      NaN
# 8      NaN      NaN
# 9      NaN      NaN
# ['id', 'pj_no', 'tc_mseki', 'tt_mseki', 'levelplan', 'fukuin', 'road_st', 'magutchi', 'setsudo_hi', 'setsudo_kj', 'jigata', 'hiatari', 'niwasaki', 'garage', 'kobetsu1', 'kobetsu2', 'kobetsu3', 'kobetsu4']
# 18

# %% [markdown]
# ### 応募用サンプルファイル	(sample_submit.tsv)
# - 1列目に"id"を、2列目に"id"に対応する"keiyaku_pr"を記入したファイルを、ヘッダ無しtsv形式で投稿する。

# %%
sample_submit = pd.read_csv('dataset/sample_submit.tsv', delimiter='\t')
print(sample_submit.head(10))
# Out:
#    test_0000  19588164
# 0  test_0001  26903494
# 1  test_0002  26878754
# 2  test_0003  26878754
# 3  test_0004  27112940
# 4  test_0005  26878754
# 5  test_0006  26878754
# 6  test_0007  26878754
# 7  test_0008  26636112
# 8  test_0009  28987098
# 9  test_0010  26878754
